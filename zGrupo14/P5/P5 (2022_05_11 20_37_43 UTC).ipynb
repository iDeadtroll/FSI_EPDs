# %% [markdown]
# # Problema 5 #

# %%
import pandas as pd
df = pd.read_csv("14_FootballClubs.csv",encoding = "ISO-8859-1")
filtrado_tamanio = df.loc[df["Average_Age_Of_Players"] > 27 ,["Club_Name","Competition Name"]]
filtrado_tamanio
# Out:
#                         Club_Name  Competition Name
# 0                 Manchester City    Premier League
# 2               Manchester United    Premier League
# 4                    Liverpool FC    Premier League
# 6                     Real Madrid            LaLiga
# 7             AtlÃ©tico de Madrid            LaLiga
# 11                    Juventus FC           Serie A
# 13                 Leicester City    Premier League
# 14                    Inter Milan           Serie A
# 15                     SSC Napoli           Serie A
# 19                     Everton FC    Premier League
# 20                     Sevilla FC            LaLiga
# 21                    Atalanta BC           Serie A
# 27                West Ham United    Premier League
# 30                  Villarreal CF            LaLiga
# 31                       SS Lazio           Serie A
# 43                 Crystal Palace    Premier League
# 44               Newcastle United    Premier League
# ...

# %% [markdown]
# # Hemos filtrado las columnas de los nombres del club y sus competiciones según los equipos que tienen una media de edad en sus jugadores mayores de 27 años #

# %%
df_mod = df[['Club_Name','Average_Age_Of_Players']]
df_2 = df_mod.groupby(['Club_Name'])[['Average_Age_Of_Players']].sum()
df_2.head()
# Out:
#                  Average_Age_Of_Players
# Club_Name
# 1.FSV Mainz 05                     25.7
# AC Milan                           26.8
# ACF Fiorentina                     27.0
# AFC Bournemouth                    25.7
# AS Monaco                          24.4

# %% [markdown]
# # Hemos creado un nuevo data frame con las columnas Club Name y Age of Players ordenando los nombres de los clubes por orden alfabetico #
